# %%
import pandas as pd
import numpy as np
from scipy import stats
from pathlib import Path

# 设置文件路径
base_path = Path("../../../data/ml_dataset")
target_columns = ['CH4', 'N2O', 'SOCSR', 'Yield', 'NH3', 'NL', 'NR', 'NO']

# 加载第一个文件获取特征列名
first_file = base_path / f"{target_columns[0]}.csv"
first_df = pd.read_csv(first_file)
feature_columns = first_df.columns[:-1].tolist()  # 假设最后一列是目标变量

# 初始化结果DataFrame
corr_df = pd.DataFrame(index=target_columns, columns=feature_columns)
pval_df = pd.DataFrame(index=target_columns, columns=feature_columns)
sig_df = pd.DataFrame(index=target_columns, columns=feature_columns)

# 计算相关系数
for target in target_columns:
    file_path = base_path / f"{target}.csv"
    df = pd.read_csv(file_path)
    
    # 确保最后一列是目标变量
    if df.columns[-1] != target:
        print(f"注意: {target}.csv的最后一列是'{df.columns[-1]}'，不是'{target}'")
        target_col = df.columns[-1]
    else:
        target_col = target
    
    # 为每个特征计算Spearman相关系数
    for feature in feature_columns:
        if feature in df.columns:
            corr, pval = stats.spearmanr(df[feature], df[target_col], nan_policy='omit')
            corr_df.loc[target, feature] = corr
            pval_df.loc[target, feature] = pval
            sig_df.loc[target, feature] = 'Yes' if pval < 0.05 else 'No'

# 转换数据类型
corr_df = corr_df.astype(float)
pval_df = pval_df.astype(float)

# 保存结果
corr_df.to_csv('spearman_correlation.csv')
pval_df.to_csv('spearman_pvalue.csv')
sig_df.to_csv('significance.csv')

print("结果已保存:")
print(f"1. spearman_correlation.csv - 相关系数矩阵")
print(f"2. spearman_pvalue.csv - p值矩阵")
print(f"3. significance.csv - 显著性矩阵 (p < 0.05)")
print("\n数据形状:")
print(f"相关系数矩阵: {corr_df.shape}")
print(f"p值矩阵: {pval_df.shape}")
print(f"显著性矩阵: {sig_df.shape}")
# Out:
# 结果已保存:
# 1. spearman_correlation.csv - 相关系数矩阵
# 2. spearman_pvalue.csv - p值矩阵
# 3. significance.csv - 显著性矩阵 (p < 0.05)
#
# 数据形状:
# 相关系数矩阵: (8, 28)
# p值矩阵: (8, 28)
# 显著性矩阵: (8, 28)
# C:\Users\JZ\AppData\Local\Temp\ipykernel_478116\2352005279.py:35: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, pval = stats.spearmanr(df[feature], df[target_col], nan_policy='omit')
# C:\Users\JZ\AppData\Local\Temp\ipykernel_478116\2352005279.py:35: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, pval = stats.spearmanr(df[feature], df[target_col], nan_policy='omit')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
from matplotlib.colors import LinearSegmentedColormap

# 定义重命名和排序字典
name_dict = {
    "STRAW": " Straw",
    "OrgN": "Organic N",
    "WM_AWD": "II",
    "BULK_DENSITY": "Bulk density",
    "IK": "Inorganic K",
    "pet": "PET",
    "SILT": "Silt",
    "frs": "Frost days",
    "SOM": "SOM",
    "wet": "Wet days",
    "WM_CF": "CF",
    "vap": "VAP",
    "TN": "Soil total N",
    "IP": "Inorganic P",
    "dtr": "DTR",
    "PH": "Soil PH",
    "CLAY": "Clay",
    "IN": "Inorganic N",
    "tmx": "TMX",
    "SAND": "Sand",
    "pre": "Precipitation",
    "temp": "TMP",
    "WM_MD": "MD",
    "tmn": "TMN",
    "WM_RF": "Rainfed",
    "BC": "Biochar",
    "tillage": "Tillage",
    "TYPE_IN": "SRF"
}

target_name_dict = {
    "CH4": f"$\mathregular{{CH_{4}}}$",
    "N2O": f"$\mathregular{{N_{2}O}}$", 
    "SOCSR": "ΔSOC",
    "Yield": "Yield",
    "NH3": f"$\mathregular{{NH_{3}}}$",
    "NL": "N leaching",
    "NR": "N runoff",
    "NO": "$\mathregular{{NO}}$"
}

target_sort_order = ["CH4", "N2O", "SOCSR", "Yield", "NH3", "NL", "NR", "NO"]

custom_source_order = [
    # Climate类特征
    "TMP", "TMX", "TMN", "Precipitation", "PET", "Frost days", "Wet days", "VAP", "DTR",
    # Soil类特征
    "Sand", "Silt", "Clay", "Soil PH", "Soil total N", "SOM", "Bulk density",
    # AMPs类特征
    "Inorganic N", "SRF", "Inorganic P",
    "Inorganic K",
    "Organic N",
    " Straw",
    "CF",
    "MD",
    "II",
    "Rainfed",
    "Biochar",
    "Tillage",
]

def plot_correlation_matrix(corr_df, pval_df, sig_df, output_path='correlation_heatmap.tif'):
    """
    绘制相关系数网格图
    """
    # 设置字体
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['axes.grid'] = False
    
    # 重命名目标变量（行）
    corr_df_renamed_rows = corr_df.rename(index=target_name_dict)
    pval_df_renamed_rows = pval_df.rename(index=target_name_dict)
    sig_df_renamed_rows = sig_df.rename(index=target_name_dict)
    
    # 重命名特征（列）
    corr_df_renamed = corr_df_renamed_rows.rename(columns=name_dict)
    pval_df_renamed = pval_df_renamed_rows.rename(columns=name_dict)
    sig_df_renamed = sig_df_renamed_rows.rename(columns=name_dict)
    
    # 按照target_sort_order排序行
    # 注意：target_sort_order中的是原始名称，需要转换为重命名后的名称
    target_sort_order_renamed = [target_name_dict.get(t, t) for t in target_sort_order]
    
    # 检查是否所有目标都在数据中
    available_targets = [t for t in target_sort_order_renamed if t in corr_df_renamed.index]
    corr_df_sorted = corr_df_renamed.loc[available_targets]
    pval_df_sorted = pval_df_renamed.loc[available_targets]
    sig_df_sorted = sig_df_renamed.loc[available_targets]
    
    # 按照custom_source_order排序列
    # 只保留custom_source_order中存在且实际在数据中的特征
    available_features = [f for f in custom_source_order if f in corr_df_sorted.columns]
    
    # 确保所有自定义顺序中的特征都存在，如果不存在则添加NaN列
    final_features = []
    for feature in custom_source_order:
        if feature in corr_df_sorted.columns:
            final_features.append(feature)
    
    corr_df_final = corr_df_sorted[final_features]
    pval_df_final = pval_df_sorted[final_features]
    sig_df_final = sig_df_sorted[final_features]
    
    # 创建图形
    fig, ax = plt.subplots(figsize=(20, 10), facecolor='none', edgecolor='none')
    
    # 颜色映射
    cmap = LinearSegmentedColormap.from_list('rdbu', ['#1f77b4', '#ffffff', '#d62728'])
    
    # 颜色范围
    corr_values = corr_df_final.values
    vmax = max(abs(np.nanmin(corr_values)), abs(np.nanmax(corr_values)))
    vmin = -vmax
    
    # 绘制热图
    im = ax.imshow(corr_df_final.values, cmap=cmap, vmin=vmin, vmax=vmax, aspect='equal')
    
    # 颜色条
    cbar = plt.colorbar(im, ax=ax, fraction=0.015, pad=0.03)
    cbar.set_label('Spearman correlation coefficient', fontsize=26)
    
    # 设置坐标轴
    ax.set_xticks(np.arange(len(corr_df_final.columns)))
    ax.set_yticks(np.arange(len(corr_df_final.index)))
    
    # ====== 新增/修改：将X轴刻度放在上方 ======
    ax.xaxis.tick_top()  # 把X轴刻度移到顶部
    ax.set_xticklabels(corr_df_final.columns, rotation=45, ha='left', fontsize=24)  # ha改为left（适配顶部刻度）
    # =========================================
    ax.set_yticklabels(corr_df_final.index, fontsize=24)
    
    # 绘制单元格内容和显著性标记
    for i in range(len(corr_df_final.index)):
        for j in range(len(corr_df_final.columns)):
            corr_value = corr_df_final.iloc[i, j]
            p_value = pval_df_final.iloc[i, j]
            
            # 检查是否为NaN
            if pd.isna(corr_value) or pd.isna(p_value):
                # 绘制灰色背景
                rect = plt.Rectangle((j-0.5, i-0.5), 1, 1, 
                                    fill=True, color='lightgray', alpha=0.5)
                ax.add_patch(rect)
                # 绘制X标记
                ax.plot(j, i, 'x', color='darkgray', markersize=15, markeredgewidth=2)
                continue
            
            # 判断显著性并绘制不同大小的圆圈
            if p_value < 0.001:
                circle_radius = 0.25
            elif p_value < 0.01:
                circle_radius = 0.18
            elif p_value < 0.05:
                circle_radius = 0.12
            else:
                # 不显著 - 绘制灰色背景和X标记
                rect = plt.Rectangle((j-0.5, i-0.5), 1, 1, 
                                    fill=True, color='lightgray', alpha=0.5)
                ax.add_patch(rect)
                ax.plot(j, i, 'x', color='darkgray', markersize=15, markeredgewidth=2)
                continue
            
            # 绘制表示显著性的圆圈
            circle = mpatches.Circle((j, i), circle_radius, 
                                     edgecolor='black', facecolor='none', 
                                     linewidth=1.5)
            ax.add_patch(circle)
    
    # 创建图例
    legend_elements = [
        plt.Line2D([0], [0], marker='o', color='w', markeredgecolor='black', 
                   markersize=12*0.85, markeredgewidth=1.5, linestyle='', 
                   label='p < 0.05'),
        plt.Line2D([0], [0], marker='o', color='w', markeredgecolor='black', 
                   markersize=18*0.85, markeredgewidth=1.5, linestyle='', 
                   label='p < 0.01'),
        plt.Line2D([0], [0], marker='o', color='w', markeredgecolor='black', 
                   markersize=25*0.85, markeredgewidth=1.5, linestyle='', 
                   label='p < 0.001'),
        plt.Line2D([0], [0], marker='x', color='darkgray', markersize=12, 
                  markeredgewidth=1.5, linestyle='', label='Not significant')
    ]
    
    # 添加图例
    # 添加图例
    legend = ax.legend(handles=legend_elements, 
                      loc='lower center',  # 改为下方居中
                      bbox_to_anchor=(0.5, -0.15),  # 调整垂直位置（负值表示在图下方）
                      ncol=4,
                      fontsize=20, 
                      frameon=False,
                      fancybox=False,
                      shadow=False,
                      borderaxespad=0.5)
    
    # 设置颜色条字体
    cbar.ax.tick_params(labelsize=20)
    
    # 调整布局
    plt.tight_layout()
    
    # 保存图形
    if output_path:
        plt.savefig(output_path, dpi=300, bbox_inches='tight', format='tiff')
        print(f"热图已保存为: {output_path}")
    
    plt.show()
    
    # 打印一些信息
    print(f"目标变量顺序: {list(corr_df_final.index)}")
    print(f"特征顺序: {list(corr_df_final.columns)}")
    print(f"数据形状: {corr_df_final.shape}")
    
    return corr_df_final, pval_df_final, sig_df_final

# 主程序
if __name__ == "__main__":
    # 加载三个CSV文件
    try:
        # 读取相关系数矩阵
        corr_df = pd.read_csv('spearman_correlation.csv', index_col=0)
        print(f"加载相关系数矩阵: {corr_df.shape}")
        
        # 读取p值矩阵
        pval_df = pd.read_csv('spearman_pvalue.csv', index_col=0)
        print(f"加载p值矩阵: {pval_df.shape}")
        
        # 读取显著性矩阵
        sig_df = pd.read_csv('significance.csv', index_col=0)
        print(f"加载显著性矩阵: {sig_df.shape}")
        
        # 检查三个矩阵的形状是否一致
        if corr_df.shape != pval_df.shape or corr_df.shape != sig_df.shape:
            print("警告: 三个矩阵的形状不一致!")
            print(f"相关系数矩阵形状: {corr_df.shape}")
            print(f"p值矩阵形状: {pval_df.shape}")
            print(f"显著性矩阵形状: {sig_df.shape}")
        
        # 绘制热图
        corr_final, pval_final, sig_final = plot_correlation_matrix(
            corr_df, pval_df, sig_df, 
            output_path='correlation_heatmap.tif'
        )
        
        # 可选：保存重命名和排序后的数据
        corr_final.to_csv('correlation_sorted.csv')
        pval_final.to_csv('pvalue_sorted.csv')
        sig_final.to_csv('significance_sorted.csv')
        print("排序后的数据已保存为CSV文件")
        
    except FileNotFoundError as e:
        print(f"文件未找到: {e}")
        print("请确保以下文件在当前目录中:")
        print("1. spearman_correlation.csv")
        print("2. spearman_pvalue.csv")
        print("3. significance.csv")
    except Exception as e:
        print(f"发生错误: {e}")
# Out:
# 加载相关系数矩阵: (8, 28)
# 加载p值矩阵: (8, 28)
# 加载显著性矩阵: (8, 28)
# 热图已保存为: correlation_heatmap.tif
# 目标变量顺序: ['$\\mathregular{CH_4}$', '$\\mathregular{N_2O}$', 'ΔSOC', 'Yield', '$\\mathregular{NH_3}$', 'N leaching', 'N runoff', '$\\mathregular{{NO}}$']
# 特征顺序: ['TMP', 'TMX', 'TMN', 'Precipitation', 'PET', 'Frost days', 'Wet days', 'VAP', 'DTR', 'Sand', 'Silt', 'Clay', 'Soil PH', 'Soil total N', 'SOM', 'Bulk density', 'Inorganic N', 'SRF', 'Inorganic P', 'Inorganic K', 'Organic N', ' Straw', 'CF', 'MD', 'II', 'Rainfed', 'Biochar', 'Tillage']
# 数据形状: (8, 28)
# 排序后的数据已保存为CSV文件
